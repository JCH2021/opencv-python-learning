# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
img = cv2.imread('girl.jpg')
img = img[:,:,::-1]
dst = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)
#参数三是节亮度组件的滤波器强度，越大越好，移除噪声的同时会移除一些细节
#参数四是和参数三一样的效果，只是针对颜色成分的
#参数五是用于计算权重的模板面片的大小（以像素为单位）
#参数六是用于计算给定像素加权平均值的窗口大小（以像素为单位）
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(dst)
