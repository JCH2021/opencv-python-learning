# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread('nitianerxing.jpg')
img = img[:,:,::-1]
#颜色问题可能就是 RGB 与 BGR 的转换问题
plt.imshow(img)

# %%
pixel = img[600,500] #位于坐标(600,500)处的像素值
pixel
# Out:
# array([ 87, 125, 112], dtype=uint8)

# %%
img[1600:1700,100:200] = [255,255,0]
#将某一区域的颜色给改了
plt.imshow(img)

# %%
img.shape #图像属性，字面上看就是高、宽、通道数(RGB)
#其实对应的是数组的 shape
# Out:
# (1800, 1080, 3)

# %%
r,g,b = cv2.split(img)
#通道切分，之前已经将 RGB 转好了
#切分也可以通过数组的切片操作，如下：
# r,g,b = img[:,:,0],img[:,:,1],img[:,:,2]
plt.imshow(b)

# %%
img = cv2.merge((r,g,b))
#将通道又合并回来
plt.imshow(img)

# %% [markdown]
# 因为我觉得有些对科研可能用不到，所以就不讲述了
